# %%
load("../framework/instance_gen.sage")

verbosity = 2

def build_b2_hat_law(p=3):
    D = {}
    D[-1]=5./16
    D[0]=6./16
    D[1]=5./16
    return D

# CTRU-512 parameters
print("============= CTRU-512-B2-hat")
n = 512
m = 512
q = 3457
D_s = build_b2_hat_law(3)
D_e = D_s

_, _, inst = initialize_from_LWE_instance(DBDD_predict_diag, n, q,
                                          m, D_e, D_s, verbosity=verbosity)

inst.integrate_q_vectors(q, report_every=20)
print(" Attack Estimation via GSA + Interesect model ")
inst.estimate_attack()
print(" Attack Estimation via simulation + probabilistic model ")
inst.estimate_attack(probabilistic=True, lift_union_bound=True, silent=False)

print("============= CTRU-768-B2-hat")

# CTRU-768 parameters
n = 768
m = 768
q = 3457
D_s = build_b2_hat_law(3)
D_e = D_s

_, _, inst = initialize_from_LWE_instance(DBDD_predict_diag, n, q,
                                          m, D_e, D_s, verbosity=verbosity)

inst.integrate_q_vectors(q, report_every=20)
print(" Attack Estimation via GSA + Interesect model ")
inst.estimate_attack()
print(" Attack Estimation via simulation + probabilistic model ")

inst.estimate_attack(probabilistic=True, lift_union_bound=True, silent=False)

print("============= CTRU-1024-B2-hat")

# CTRU-1024 parameters
n = 1024
m = 1024
q = 3457
D_s = build_b2_hat_law(3)
D_e = D_s

_, _, inst = initialize_from_LWE_instance(DBDD_predict_diag, n, q,
                                          m, D_e, D_s, verbosity=verbosity)

inst.integrate_q_vectors(q, report_every=20)
print(" Attack Estimation via GSA + Interesect model ")
inst.estimate_attack()
print(" Attack Estimation via simulation + probabilistic model ")
inst.estimate_attack(probabilistic=True, lift_union_bound=True, silent=False)
# Out:
# ============= CTRU-512-B2-hat
#       Build DBDD from LWE
#  n=512 	 m=512 	 q=3457
#        Integrating q-vectors
#  [...20]   integrate short vector hint   3457*c1023 ∈ Λ   	 Worthy hint !   dim=1024, δ=1.00432883, β=354.38
#  [...20]   integrate short vector hint   3457*c1003 ∈ Λ   	 Worthy hint !   dim=1004, δ=1.00433255, β=353.86
#  [...20]   integrate short vector hint   3457*c983 ∈ Λ   	 Worthy hint !   dim=984, δ=1.00433442, β=353.67
#  Attack Estimation via GSA + Interesect model
#        Attack Estimation
#  ln(dvol)=4060.4053087 	 ln(Bvol)=3829.6335268 	 ln(Svol)=-461.5435639 	δ(β)=1.004334
#  dim=983 	 δ=1.004334 	 β=353.67
#
#  Attack Estimation via simulation + probabilistic model
# β= 348,	 pr=1.1842e-04, 	 cum-pr=1.9262e-04 	 rem-pr=9.9981e-0100
# β= 349,	 pr=2.8597e-04, 	 cum-pr=4.7854e-04 	 rem-pr=9.9952e-01
# β= 350,	 pr=6.5926e-04, 	 cum-pr=1.1375e-03 	 rem-pr=9.9886e-01
# β= 351,	 pr=1.4503e-03, 	 cum-pr=2.5861e-03 	 rem-pr=9.9741e-01
# β= 352,	 pr=3.0434e-03, 	 cum-pr=5.6216e-03 	 rem-pr=9.9438e-01
# β= 353,	 pr=6.0901e-03, 	 cum-pr=1.1678e-02 	 rem-pr=9.8832e-01
# β= 354,	 pr=1.1619e-02, 	 cum-pr=2.3161e-02 	 rem-pr=9.7684e-01
# β= 355,	 pr=2.1130e-02, 	 cum-pr=4.3802e-02 	 rem-pr=9.5620e-01
# β= 356,	 pr=3.6631e-02, 	 cum-pr=7.8828e-02 	 rem-pr=9.2117e-01
# β= 357,	 pr=6.0541e-02, 	 cum-pr=1.3460e-01 	 rem-pr=8.6540e-01
# β= 358,	 pr=9.5418e-02, 	 cum-pr=2.1717e-01 	 rem-pr=7.8283e-01
# β= 359,	 pr=1.4349e-01, 	 cum-pr=3.2950e-01 	 rem-pr=6.7050e-01
# β= 360,	 pr=2.0605e-01, 	 cum-pr=4.6765e-01 	 rem-pr=5.3235e-01
# β= 361,	 pr=2.8283e-01, 	 cum-pr=6.1822e-01 	 rem-pr=3.8178e-01
# β= 362,	 pr=3.7164e-01, 	 cum-pr=7.6010e-01 	 rem-pr=2.3990e-01
# β= 363,	 pr=4.6839e-01, 	 cum-pr=8.7247e-01 	 rem-pr=1.2753e-01
# β= 364,	 pr=5.6753e-01, 	 cum-pr=9.4485e-01 	 rem-pr=5.5154e-02
# β= 365,	 pr=6.6301e-01, 	 cum-pr=9.8141e-01 	 rem-pr=1.8586e-02
# β= 366,	 pr=7.4938e-01, 	 cum-pr=9.9534e-01 	 rem-pr=4.6579e-03
# β= 367,	 pr=8.2268e-01, 	 cum-pr=9.9917e-01 	 rem-pr=8.2594e-04
#        Attack Estimation
#  ln(dvol)=4060.4053087 	 ln(Bvol)=3829.6335268 	 ln(Svol)=-461.5435639 	δ(β)=1.004278
#  dim=983 	 	 	 β=360.51
#
# ============= CTRU-768-B2-hat
#       Build DBDD from LWE
#  n=768 	 m=768 	 q=3457
#        Integrating q-vectors
#  [...20]   integrate short vector hint   3457*c1535 ∈ Λ   	 Worthy hint !   dim=1536, δ=1.00304332, β=584.48
#  [...20]   integrate short vector hint   3457*c1515 ∈ Λ   	 Worthy hint !   dim=1516, δ=1.00304737, β=583.42
#  [...20]   integrate short vector hint   3457*c1495 ∈ Λ   	 Worthy hint !   dim=1496, δ=1.00305056, β=582.55
#  [...20]   integrate short vector hint   3457*c1475 ∈ Λ   	 Worthy hint !   dim=1476, δ=1.00305282, β=581.91
#  [...20]   integrate short vector hint   3457*c1455 ∈ Λ   	 Worthy hint !   dim=1456, δ=1.00305464, β=581.49
#  [...20]   integrate short vector hint   3457*c1435 ∈ Λ   	 Worthy hint !   dim=1436, δ=1.00305539, β=581.32
#  Attack Estimation via GSA + Interesect model
#        Attack Estimation
#  ln(dvol)=5746.8984746 	 ln(Bvol)=5410.3758761 	 ln(Svol)=-673.0451971 	δ(β)=1.003055
#  dim=1433 	 δ=1.003055 	 β=581.32
#
#  Attack Estimation via simulation + probabilistic model
# β= 580,	 pr=1.0954e-04, 	 cum-pr=1.9553e-04 	 rem-pr=9.9980e-0100
# β= 581,	 pr=2.3466e-04, 	 cum-pr=4.3015e-04 	 rem-pr=9.9957e-01
# β= 582,	 pr=4.8554e-04, 	 cum-pr=9.1548e-04 	 rem-pr=9.9908e-01
# β= 583,	 pr=9.7018e-04, 	 cum-pr=1.8848e-03 	 rem-pr=9.9812e-01
# β= 584,	 pr=1.8718e-03, 	 cum-pr=3.7531e-03 	 rem-pr=9.9625e-01
# β= 585,	 pr=3.4866e-03, 	 cum-pr=7.2266e-03 	 rem-pr=9.9277e-01
# β= 586,	 pr=6.2699e-03, 	 cum-pr=1.3451e-02 	 rem-pr=9.8655e-01
# β= 587,	 pr=1.0884e-02, 	 cum-pr=2.4189e-02 	 rem-pr=9.7581e-01
# β= 588,	 pr=1.8241e-02, 	 cum-pr=4.1989e-02 	 rem-pr=9.5801e-01
# β= 589,	 pr=2.9513e-02, 	 cum-pr=7.0263e-02 	 rem-pr=9.2974e-01
# β= 590,	 pr=4.6110e-02, 	 cum-pr=1.1313e-01 	 rem-pr=8.8687e-01
# β= 591,	 pr=6.9578e-02, 	 cum-pr=1.7484e-01 	 rem-pr=8.2516e-01
# β= 592,	 pr=1.0144e-01, 	 cum-pr=2.5854e-01 	 rem-pr=7.4146e-01
# β= 593,	 pr=1.4294e-01, 	 cum-pr=3.6452e-01 	 rem-pr=6.3548e-01
# β= 594,	 pr=1.9480e-01, 	 cum-pr=4.8832e-01 	 rem-pr=5.1168e-01
# β= 595,	 pr=2.5695e-01, 	 cum-pr=6.1979e-01 	 rem-pr=3.8021e-01
# β= 596,	 pr=3.2832e-01, 	 cum-pr=7.4462e-01 	 rem-pr=2.5538e-01
# β= 597,	 pr=4.0684e-01, 	 cum-pr=8.4852e-01 	 rem-pr=1.5148e-01
# β= 598,	 pr=4.8959e-01, 	 cum-pr=9.2268e-01 	 rem-pr=7.7317e-02
# β= 599,	 pr=5.7306e-01, 	 cum-pr=9.6699e-01 	 rem-pr=3.3010e-02
# β= 600,	 pr=6.5362e-01, 	 cum-pr=9.8857e-01 	 rem-pr=1.1434e-02
# β= 601,	 pr=7.2798e-01, 	 cum-pr=9.9689e-01 	 rem-pr=3.1103e-03
# β= 602,	 pr=7.9362e-01, 	 cum-pr=9.9936e-01 	 rem-pr=6.4191e-04
#        Attack Estimation
#  ln(dvol)=5746.8984746 	 ln(Bvol)=5410.3758761 	 ln(Svol)=-673.0451971 	δ(β)=1.003006
#  dim=1433 	 	 	 β=594.35
#
# ============= CTRU-1024-B2-hat
#       Build DBDD from LWE
#  n=1024 	 m=1024 	 q=3457
#        Integrating q-vectors
#  [...20]   integrate short vector hint   3457*c2047 ∈ Λ   	 Worthy hint !   dim=2048, δ=1.00236416, β=823.75
#  [...20]   integrate short vector hint   3457*c2027 ∈ Λ   	 Worthy hint !   dim=2028, δ=1.00236733, β=822.33
#  [...20]   integrate short vector hint   3457*c2007 ∈ Λ   	 Worthy hint !   dim=2008, δ=1.00237017, β=821.06
#  [...20]   integrate short vector hint   3457*c1987 ∈ Λ   	 Worthy hint !   dim=1988, δ=1.00237234, β=819.93
#  [...20]   integrate short vector hint   3457*c1967 ∈ Λ   	 Worthy hint !   dim=1968, δ=1.00237443, β=818.96
#  [...20]   integrate short vector hint   3457*c1947 ∈ Λ   	 Worthy hint !   dim=1948, δ=1.00237641, β=818.16
#  [...20]   integrate short vector hint   3457*c1927 ∈ Λ   	 Worthy hint !   dim=1928, δ=1.00237766, β=817.53
#  [...20]   integrate short vector hint   3457*c1907 ∈ Λ   	 Worthy hint !   dim=1908, δ=1.00237876, β=817.09
#  [...20]   integrate short vector hint   3457*c1887 ∈ Λ   	 Worthy hint !   dim=1888, δ=1.00237905, β=816.85
#  Attack Estimation via GSA + Interesect model
#        Attack Estimation
#  ln(dvol)=7366.3263745 	 ln(Bvol)=6925.9329739 	 ln(Svol)=-880.7868012 	δ(β)=1.002379
#  dim=1875 	 δ=1.002379 	 β=816.80
#
#  Attack Estimation via simulation + probabilistic model
# β= 820,	 pr=6.3448e-05, 	 cum-pr=1.1975e-04 	 rem-pr=9.9988e-0100
# β= 821,	 pr=1.2825e-04, 	 cum-pr=2.4799e-04 	 rem-pr=9.9975e-01
# β= 822,	 pr=2.5209e-04, 	 cum-pr=5.0002e-04 	 rem-pr=9.9950e-01
# β= 823,	 pr=4.8182e-04, 	 cum-pr=9.8160e-04 	 rem-pr=9.9902e-01
# β= 824,	 pr=8.9537e-04, 	 cum-pr=1.8761e-03 	 rem-pr=9.9812e-01
# β= 825,	 pr=1.6177e-03, 	 cum-pr=3.4907e-03 	 rem-pr=9.9651e-01
# β= 826,	 pr=2.8414e-03, 	 cum-pr=6.3222e-03 	 rem-pr=9.9368e-01
# β= 827,	 pr=4.8518e-03, 	 cum-pr=1.1143e-02 	 rem-pr=9.8886e-01
# β= 828,	 pr=8.0543e-03, 	 cum-pr=1.9108e-02 	 rem-pr=9.8089e-01
# β= 829,	 pr=1.2999e-02, 	 cum-pr=3.1859e-02 	 rem-pr=9.6814e-01
# β= 830,	 pr=2.0398e-02, 	 cum-pr=5.1607e-02 	 rem-pr=9.4839e-01
# β= 831,	 pr=3.1126e-02, 	 cum-pr=8.1127e-02 	 rem-pr=9.1887e-01
# β= 832,	 pr=4.6190e-02, 	 cum-pr=1.2357e-01 	 rem-pr=8.7643e-01
# β= 833,	 pr=6.6677e-02, 	 cum-pr=1.8201e-01 	 rem-pr=8.1799e-01
# β= 834,	 pr=9.3652e-02, 	 cum-pr=2.5861e-01 	 rem-pr=7.4139e-01
# β= 835,	 pr=1.2803e-01, 	 cum-pr=3.5354e-01 	 rem-pr=6.4646e-01
# β= 836,	 pr=1.7043e-01, 	 cum-pr=4.6372e-01 	 rem-pr=5.3628e-01
# β= 837,	 pr=2.2103e-01, 	 cum-pr=5.8225e-01 	 rem-pr=4.1775e-01
# β= 838,	 pr=2.7943e-01, 	 cum-pr=6.9898e-01 	 rem-pr=3.0102e-01
# β= 839,	 pr=3.4461e-01, 	 cum-pr=8.0272e-01 	 rem-pr=1.9728e-01
# β= 840,	 pr=4.1495e-01, 	 cum-pr=8.8458e-01 	 rem-pr=1.1542e-01
# β= 841,	 pr=4.8831e-01, 	 cum-pr=9.4094e-01 	 rem-pr=5.9059e-02
# β= 842,	 pr=5.6224e-01, 	 cum-pr=9.7415e-01 	 rem-pr=2.5854e-02
# β= 843,	 pr=6.3423e-01, 	 cum-pr=9.9054e-01 	 rem-pr=9.4565e-03
# β= 844,	 pr=7.0192e-01, 	 cum-pr=9.9718e-01 	 rem-pr=2.8188e-03
# β= 845,	 pr=7.6339e-01, 	 cum-pr=9.9933e-01 	 rem-pr=6.6696e-04
#        Attack Estimation
#  ln(dvol)=7366.3263745 	 ln(Bvol)=6925.9329739 	 ln(Svol)=-880.7868012 	δ(β)=1.002337
#  dim=1875 	 	 	 β=836.54
# (836.538727419384, None)
